# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from utils import load_log

log_file = 'log/round4_empty.log'
activity, trade, observation = load_log(log_file)
# Out:
# c:\Users\hnxxz\Documents\MATLAB\Prosperity-Trader\JM\analysis\utils.py:44: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   trade_history = pd.read_json(trade_history)

# %%
activity
# Out:
#                               bid_price_1  bid_volume_1  bid_price_2  \
# product        day timestamp
# ORCHIDS        3   0                 1090             8       1089.0
# CHOCOLATE      3   0                 7750           136          NaN
# GIFT_BASKET    3   0                69548             2      69547.0
# AMETHYSTS      3   0                 9996             2       9995.0
# STARFRUIT      3   0                 5002             1       5001.0
# ...                                   ...           ...          ...
#                    99900             4977            27          NaN
# GIFT_BASKET    3   99900            69440             1      69439.0
# COCONUT_COUPON 3   99900              597            40          NaN
# ORCHIDS        3   99900             1051            10       1049.0
# STRAWBERRIES   3   99900             3967           267          NaN
#
#                               bid_volume_2  bid_price_3  bid_volume_3  \
# product        day timestamp
# ...

# %%
(observation.TRANSPORT_FEES + observation.IMPORT_TARIFF).plot()
plt.show()
